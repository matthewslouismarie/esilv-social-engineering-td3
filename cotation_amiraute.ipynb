# %% [markdown]
# # Social Engineering - TD3 - Exercice 4

# %% [markdown]
# ### Libraries

# %%
import pandas as pd

# %%
from IPython.display import display, Markdown, Latex
def mk(content):
    display(Markdown(content))

# %% [markdown]
# ### Chargement et sélection des données

# %%
df = pd.read_csv('dataset_unifie.csv')
df['platform'].unique()
# Out:
# array(['x', 'facebook', 'info-verité-citoyenne.net', 'ouest-france.fr',
#        'sciencesenviro-journal.fr', 'le-patriote-francais.com'],
#       dtype=object)

# %% [markdown]
# Nous prendrons 3 ou 4 posts par plateforme.

# %%
df_posts = df[df['platform'] == 'facebook'][:3]
df_tweets = df[df['platform'] == 'x'][:3]
df_articles = df[(df['platform'] != 'facebook') & (df['platform'] != 'x')][:4]
df_samples = pd.concat([df_posts, df_tweets, df_articles])
df_samples
# Out:
#     Unnamed: 0                   platform  \
# 1            0                   facebook
# 2            1                   facebook
# 4            2                   facebook
# 0            0                          x
# 3            1                          x
# 5            2                          x
# 13           0  info-verité-citoyenne.net
# 38           1            ouest-france.fr
# 61           3  sciencesenviro-journal.fr
# 62           2   le-patriote-francais.com
#
#                                        author                 date  \
# 1              Collectif Anti-Éoliennes Loire  2024-01-15 09:30:12
# 2                       Vérité Énergie France  2024-01-15 14:22:45
# 4     Transition Énergétique Pays de la Loire  2024-01-15 16:15:33
# 0                             Dr_Laurent_CNRS  2024-01-15 09:23:12
# 3                                EcoDefense44  2024-01-15 14:32:45
# 5                          Sophie_Journaliste  2024-01-15 16:47:33
# ...

# %% [markdown]
# ## Cotation du raisonnement

# %% [markdown]
# ### Affirmation 001

# %% [markdown]
# Nous allons déjà évaluer la **fiabilité de la source** en étudiant les précédents posts de l’auteur du post.

# %%
for text in df[df['author'] == df_samples.iloc[0]['author']]['content'].to_list():
    mk(text)
    print('---------------')
# Out:
# RASSEMBLEMENT URGENT ! Les autorités veulent nous imposer 150 monstres d'acier qui vont détruire notre patrimoine maritime. Rejoignez-nous samedi 10h place de la Mairie. Ensemble, nous sommes plus forts ! ✊🌊 #StopEoliennes #Loire
# ---------------
# ⚠️ ALERTE SANTÉ ⚠️
#
# Des riverains d'un parc éolien en Bretagne témoignent :
# - Insomnies chroniques à cause des infrasons
# - Maux de tête permanents
# - Stress et anxiété
# - Baisse de la valeur immobilière de 40%
#
# Les autorités sanitaires REFUSENT de reconnaître le syndrome éolien. Combien de victimes avant qu'on agisse ?!
#
# Vidéo témoignage disponible sur notre chaîne.
# ---------------
# URGENT - Ils ont avancé la date du vote en catimini ! Le conseil municipal doit se prononcer DEMAIN alors que c'était prévu le 30 ! Manoeuvre pour éviter la mobilisation ! TOUS devant la mairie demain 18h ! On ne se laissera pas voler notre démocratie !
# ---------------
# ✊ SUCCÈS DE LA MOBILISATION ✊
#
# ...

# %%
mk(f"**Texte** : {df_samples.iloc[0]['content']}")
mk(f"**Source** : {df_samples.iloc[0]['author']}")
mk("**Cotation** : **D4**")
mk("**Justification** :")
mk("- **Fiabilité source (D)** :")
mk("- Compte Facebook inconnu")
mk("- Historique de communications alarmistes, complotistes, très orientées et qui ne fournissent pas de source.")

mk("**Crédibilité information** :")
mk("- **Crédibilité information (4)** :")
mk("- Peu factuel, très orienté et alarmiste")
mk("- Aucune source")
mk("- Narratif suggérant un contenu biaisé (« Les autorités veulent nous **imposer** »)")
# Out:
# **Texte** : RASSEMBLEMENT URGENT ! Les autorités veulent nous imposer 150 monstres d'acier qui vont détruire notre patrimoine maritime. Rejoignez-nous samedi 10h place de la Mairie. Ensemble, nous sommes plus forts ! ✊🌊 #StopEoliennes #Loire
# **Source** : Collectif Anti-Éoliennes Loire
# **Cotation** : **D4**
# **Justification** :
# - **Fiabilité source (D)** :
# - Compte Facebook inconnu
# - Historique de communications alarmistes, complotistes, très orientées et qui ne fournissent pas de source.
# **Crédibilité information** :
# - **Crédibilité information (4)** :
# - Peu factuel, très orienté et alarmiste
# - Aucune source
# - Narratif suggérant un contenu biaisé (« Les autorités veulent nous **imposer** »)

# %%
mk("# Affirmation 1")
mk(f"**Texte** : {df_samples.iloc[1]['content']}")
mk(f"**Source** : {df_samples.iloc[1]['author']}")
mk("**Cotation** : **E5**")
mk("**Justification** :")
mk("- **Fiabilité source (E)** :")
mk("- Page militante au nom générique")
mk("- Aucun historique de crédibilité identifié")
mk("- Usage récurrent de rhétorique complotiste (censure, médias mainstream)")
mk("- **Crédibilité information (5)** :")
mk("- Accusations graves sans documents vérifiables")
mk("- Absence totale de sources primaires")
mk("- Appel émotionnel et incitation au partage")
# Out:
# # Affirmation 1
# **Texte** : 🚨 SCANDALE 🚨
#
# Nous avons obtenu des documents confidentiels qui prouvent que :
# - Le coût réel du projet est 3 fois supérieur aux annonces officielles
# - Des espèces protégées seront impactées (dauphins, oiseaux migrateurs)
# - Les études d'impact ont été bâclées en 3 mois au lieu de 2 ans
#
# Les médias mainstream refusent de relayer cette information. PARTAGEZ MASSIVEMENT avant la censure !
#
# #ReveilCitoyen #TransparenceMaintenant #StopEoliennes
# **Source** : Vérité Énergie France
# **Cotation** : **E5**
# **Justification** :
# - **Fiabilité source (E)** :
# - Page militante au nom générique
# - Aucun historique de crédibilité identifié
# - Usage récurrent de rhétorique complotiste (censure, médias mainstream)
# - **Crédibilité information (5)** :
# - Accusations graves sans documents vérifiables
# - Absence totale de sources primaires
# - Appel émotionnel et incitation au partage

# %%
mk("# Affirmation 2")
mk(f"**Texte** : {df_samples.iloc[2]['content']}")
mk(f"**Source** : {df_samples.iloc[2]['author']}")
mk("**Cotation** : **B2**")
mk("**Justification** :")
mk("- **Fiabilité source (B)** :")
mk("- Organisation institutionnelle régionale")
mk("- Communication publique régulière et traçable")
mk("- **Crédibilité information (2)** :")
mk("- Données chiffrées cohérentes")
mk("- Référence explicite à des documents publics vérifiables")
mk("- Ton factuel, absence de rhétorique émotionnelle")
# Out:
# # Affirmation 2
# **Texte** : Point factuel sur le projet de parc éolien offshore :
#
# ✅ 3 ans de concertation publique avec 45 réunions
# ✅ Études d'impact menées par 12 organismes indépendants
# ✅ Zone choisie pour minimiser l'impact sur la pêche (couloirs de migration préservés)
# ✅ Création de 800 emplois locaux pendant la construction
# ✅ Réduction de 450 000 tonnes de CO2/an
#
# Toutes les études sont accessibles sur le site de la préfecture. Débat constructif bienvenu ! 🌱⚡
# **Source** : Transition Énergétique Pays de la Loire
# **Cotation** : **B2**
# **Justification** :
# - **Fiabilité source (B)** :
# - Organisation institutionnelle régionale
# - Communication publique régulière et traçable
# - **Crédibilité information (2)** :
# - Données chiffrées cohérentes
# - Référence explicite à des documents publics vérifiables
# - Ton factuel, absence de rhétorique émotionnelle

# %%
mk("# Affirmation 3")
mk(f"**Texte** : {df_samples.iloc[3]['content']}")
mk(f"**Source** : {df_samples.iloc[3]['author']}")
mk("**Cotation** : **A3**")
mk("**Justification** :")
mk("- **Fiabilité source (A)** :")
mk("- Chercheur identifié affilié à un organisme scientifique reconnu")
mk("- Expertise directement liée au sujet")
mk("- **Crédibilité information (3)** :")
mk("- Affirmation plausible mais non sourcée dans le message")
mk("- Invitation à un webinaire sans publication immédiate")
# Out:
# # Affirmation 3
# **Texte** : Nos études sur l'impact des éoliennes offshore montrent des effets mineurs sur les oiseaux marins. Webinaire demain 14h sur les résultats.
# **Source** : Dr_Laurent_CNRS
# **Cotation** : **A3**
# **Justification** :
# - **Fiabilité source (A)** :
# - Chercheur identifié affilié à un organisme scientifique reconnu
# - Expertise directement liée au sujet
# - **Crédibilité information (3)** :
# - Affirmation plausible mais non sourcée dans le message
# - Invitation à un webinaire sans publication immédiate

# %%
mk("# Affirmation 4")
mk(f"**Texte** : {df_samples.iloc[4]['content']}")
mk(f"**Source** : {df_samples.iloc[4]['author']}")
mk("**Cotation** : **D4**")
mk("**Justification** :")
mk("- **Fiabilité source (D)** :")
mk("- Collectif militant local")
mk("- Absence de légitimité scientifique ou institutionnelle")
mk("- **Crédibilité information (4)** :")
mk("- Message purement mobilisateur")
mk("- Aucun fait, aucune donnée, aucune source")
mk("- Ton alarmiste")
# Out:
# # Affirmation 4
# **Texte** : URGENT ! Les éoliennes vont détruire notre littoral ! Mobilisation générale samedi 14h place de la République ! Venez nombreux !
# **Source** : EcoDefense44
# **Cotation** : **D4**
# **Justification** :
# - **Fiabilité source (D)** :
# - Collectif militant local
# - Absence de légitimité scientifique ou institutionnelle
# - **Crédibilité information (4)** :
# - Message purement mobilisateur
# - Aucun fait, aucune donnée, aucune source
# - Ton alarmiste

# %%
mk("# Affirmation 5")
mk(f"**Texte** : {df_samples.iloc[5]['content']}")
mk(f"**Source** : {df_samples.iloc[5]['author']}")
mk("**Cotation** : **B3**")
mk("**Justification** :")
mk("- **Fiabilité source (B)** :")
mk("- Journaliste identifiée")
mk("- Travail médiatique classique")
mk("- **Crédibilité information (3)** :")
mk("- Annonce d’un contenu à paraître")
mk("- Information factuelle mais non encore consultable")
# Out:
# # Affirmation 5
# **Texte** : Interview du préfet maritime sur le projet éolien offshore cet après-midi. Article complet dans Ouest-France demain matin.
# **Source** : Sophie_Journaliste
# **Cotation** : **B3**
# **Justification** :
# - **Fiabilité source (B)** :
# - Journaliste identifiée
# - Travail médiatique classique
# - **Crédibilité information (3)** :
# - Annonce d’un contenu à paraître
# - Information factuelle mais non encore consultable

# %%
mk("# Affirmation 6")
mk(f"**Texte** : {df_samples.iloc[6]['content']}")
mk(f"**Source** : {df_samples.iloc[6]['author']}")
mk("**Cotation** : **D5**")
mk("**Justification** :")
mk("- **Fiabilité source (D)** :")
mk("- Média alternatif sans reconnaissance établie")
mk("- Positionnement explicitement anti-système")
mk("- **Crédibilité information (5)** :")
mk("- Citations invérifiables")
mk("- Témoignages anecdotiques")
mk("- Accumulation d’éléments non confirmés")
mk("- Narratif complotiste (lobby, élites, médias complices)")
# Out:
# # Affirmation 6
# **Texte** : EXCLUSIF : Documents confidentiels sur le scandale du parc éolien
#
# Notre rédaction a obtenu des documents internes qui révèlent l'ampleur de la corruption autour du projet de parc éolien offshore de la Loire. Ces documents, transmis par une source au sein même de la préfecture, montrent que les décideurs politiques ont délibérément caché la vérité aux citoyens.
#
# Selon un rapport d'expertise indépendante daté du 12 novembre 2023 et marqué "confidentiel - ne pas diffuser", l'impact sur la faune marine serait catastrophique. Le rapport indique textuellement : "Les simulations acoustiques montrent que 87% des dauphins présents dans la zone seraient contraints de modifier leurs routes migratoires, entraînant un stress important et une mortalité accrue estimée entre 15% et 23% sur les cinq premières années d'exploitation."
#
# ...

# %%
mk("# Affirmation 7")
mk(f"**Texte** : {df_samples.iloc[7]['content']}")
mk(f"**Source** : {df_samples.iloc[7]['author']}")
mk("**Cotation** : **A1**")
mk("**Justification** :")
mk("- **Fiabilité source (A)** :")
mk("- Journaliste identifiée, travail d’enquête long")
mk("- Multiples sources citées")
mk("- **Crédibilité information (1)** :")
mk("- Faits sourcés, documents référencés")
mk("- Vérifications croisées")
mk("- Distinction claire faits / opinions")
# Out:
# # Affirmation 7
# **Texte** : Parc éolien offshore : démêler le vrai du faux
#
# Depuis plusieurs semaines, des informations contradictoires circulent sur les réseaux sociaux concernant le projet de parc éolien offshore au large de la Loire. Nous avons enquêté pendant six mois pour démêler le vrai du faux.
#
# LES FAITS VÉRIFIÉS :
#
# 1. Durée des études d'impact
# FAUX : "Les études ont été bâclées en 3 mois"
# VRAI : Le processus d'étude a duré 3 ans (2020-2023), conformément à la réglementation. Douze organismes indépendants ont participé, produisant 4500 pages de rapports. Tous ces documents sont accessibles sur le site de la préfecture (référence dossier E-2023-Loire-001).
#
# 2. Impact sur les dauphins
# FAUX : "87% des dauphins impactés selon une étude"
# ...

# %%
mk("# Affirmation 8")
mk(f"**Texte** : {df_samples.iloc[8]['content']}")
mk(f"**Source** : {df_samples.iloc[8]['author']}")
mk("**Cotation** : **A1**")
mk("**Justification** :")
mk("- **Fiabilité source (A)** :")
mk("- Chercheure spécialisée dans le domaine")
mk("- Références institutionnelles explicites")
mk("- **Crédibilité information (1)** :")
mk("- Méthodologie détaillée")
mk("- Comparaison avec données européennes")
mk("- Limites et incertitudes clairement exposées")
# Out:
# # Affirmation 8
# **Texte** : Éolien offshore et biodiversité marine : que disent vraiment les études ?
#
# Le débat autour du projet de parc éolien offshore soulève des questions scientifiques importantes. En tant que chercheure en écologie marine, je souhaite apporter un éclairage factuel sur les impacts réels de ce type d'infrastructure.
#
# MÉTHODOLOGIE DES ÉTUDES D'IMPACT
#
# Les études menées pour ce projet ont suivi le protocole européen standardisé comprenant :
# - 36 mois de relevés acoustiques sous-marins
# - 24 campagnes d'observation aérienne de la mégafaune
# - Analyse ADN environnemental pour cartographier la biodiversité
# - Modélisation des impacts cumulés
#
# Ce travail, coordonné par l'IFREMER et validé par le Conseil National de Protection de la Nature, constitue une base scientifique solide.
#
# RÉSULTATS CLÉS
#
# 1. Phase de construction (18 mois)
# - Impact temporaire modéré à fort sur les mammifères marins dû aux travaux de battage des pieux
# ...

# %%
mk("# Affirmation 9")
mk(f"**Texte** : {df_samples.iloc[9]['content']}")
mk(f"**Source** : {df_samples.iloc[9]['author']}")
mk("**Cotation** : **E4**")
mk("**Justification** :")
mk("- **Fiabilité source (E)** :")
mk("- Groupe idéologique partisan")
mk("- Absence de neutralité revendiquée")
mk("- **Crédibilité information (4)** :")
mk("- Mélange faits/opinions")
mk("- Sélection biaisée d’éléments médiatiques")
mk("- Narratif politique et émotionnel dominant")
# Out:
# # Affirmation 9
# **Texte** : Projet éolien : la trahison des élites contre le peuple français
#
# Une fois de plus, les élites mondialistes imposent leur vision écologiste punitive au peuple français. Le projet de parc éolien offshore de la Loire n'est que la dernière manifestation de cette dérive autoritaire qui sacrifie les intérêts nationaux sur l'autel de l'idéologie verte.
#
# Ce projet pharaonique, financé majoritairement par des capitaux étrangers (allemands et danois), ne profite qu'aux multinationales de l'énergie. Pendant ce temps, nos pêcheurs traditionnels, gardiens de notre patrimoine maritime depuis des générations, sont écartés sans ménagement.
#
# ...

# %% [markdown]
# ## Tableau synthétique

# %% [markdown]
# | ID | Source | Cotation | Texte (extrait) | Justification synthétique |
# |----|--------|----------|-----------------|---------------------------|
# | 0 | Compte Facebook inconnu | D4 | « Les autorités veulent nous imposer… » | Source inconnue et orientée ; propos alarmistes sans sources, narratif biaisé |
# | 1 | Vérité Énergie France | E5 | « Documents confidentiels… scandale… partagez avant la censure » | Page militante, rhétorique complotiste, accusations graves non vérifiables |
# | 2 | Transition Énergétique Pays de la Loire | B2 | « 3 ans de concertation… 800 emplois… études accessibles » | Source institutionnelle ; données chiffrées cohérentes et vérifiables |
# | 3 | Dr_Laurent_CNRS | A3 | « Effets mineurs sur les oiseaux marins » | Chercheur reconnu ; information plausible mais non sourcée dans le post |
# | 4 | EcoDefense44 | D4 | « URGENT ! Les éoliennes vont détruire notre littoral ! » | Collectif militant ; message mobilisateur sans faits ni données |
# | 5 | Sophie_Journaliste | B3 | « Interview du préfet maritime… article demain » | Journaliste identifiée ; annonce factuelle mais contenu non encore consultable |
# | 6 | Rédaction InfoVérité | D5 | « Corruption… rapport confidentiel… lobby éolien » | Média alternatif non reconnu ; documents invérifiables, narratif complotiste |
# | 7 | Sophie Martin, journaliste investigations | A1 | « Démêler le vrai du faux… faits vérifiés » | Enquête approfondie, sources multiples, documents publics référencés |
# | 8 | Dr. Émilie Rousseau | A1 | « Méthodologie scientifique… impacts gérables » | Analyse scientifique détaillée, références institutionnelles, limites explicitées |
# | 9 | Équipe Le Patriote | E4 | « Trahison des élites… manipulation médiatique » | Groupe idéologique partisan ; discours politique émotionnel, faits sélectionnés |

# %% [markdown]
# ## Questions synthétiques

# %% [markdown]
# ### 1. *Combien d'affirmations cotées A ou B (sources fiables) ?*
#
# Sur l’ensemble des 10 affirmations analysées (ID 0 à 9) :
#
# - **5 affirmations** proviennent de **sources fiables ou généralement fiables (A ou B)**
#   - ID 2 (B2)
#   - ID 3 (A3)
#   - ID 5 (B3)
#   - ID 7 (A1)
#   - ID 8 (A1)
#
# Cela représente **50 % du corpus**.
#
# ---
#
# ### 2. *Combien d'affirmations cotées 4 ou 5 (informations douteuses ou improbables) ?*
#
# - **5 affirmations** sont associées à une **crédibilité faible ou douteuse (4 ou 5)** :
#   - ID 0 (D4)
#   - ID 1 (E5)
#   - ID 4 (D4)
#   - ID 6 (D5)
#   - ID 9 (E4)
#
# Là aussi, **50 % du corpus** présente un contenu problématique sur le plan informationnel.
#
# ---
#
# ### 3. *Les sources D/E produisent-elles majoritairement de l'information 4/5 ?*
#
# Oui, **très clairement**.
#
# - Toutes les affirmations issues de **sources D ou E** sont associées à une **information cotée 4 ou 5** :
#   - D4 ID 0, ID 4
#   - D5 ID 6
#   - E5 ID 1
#   - E4 ID 9
#
# **Corrélation forte** entre **faible fiabilité de la source** et **faible crédibilité de l’information**.
# Cela correspond à un **pattern classique de désinformation militante ou idéologique**.
#
# ---
#
# ### 4. *Existe-t-il des cas de sources A associées à une information cotée 5 ?*
#
# **Non.**
#
# - Aucune source cotée **A** (experts scientifiques, journalistes d’investigation) ne diffuse d’information cotée 5.
# - Les sources A sont associées à des cotations **A1 ou A3**, avec :
#   - méthodologie explicite,
#   - sources vérifiables,
#   - ou prudence scientifique assumée.
#
# **Aucune erreur majeure ou compromission détectée** chez les sources fiables.
#
# ---
#
# ### 5. *Quelle affirmation est la plus dangereuse ?*
#
# **Affirmation ID 6 — Source : Rédaction InfoVérité (D5)**
#
# **Pourquoi :**
# - Source se présentant comme journalistique (illusion de crédibilité)
# - Narratif complotiste structuré (corruption, lobby, documents secrets)
# - Accusations graves (faune, corruption, coût public)
# - Mélange de pseudo-données techniques et de témoignages émotionnels
#
# **Danger élevé** car le message est **long, détaillé et persuasif**, ce qui augmente son potentiel de viralité et d’adhésion.
#
# ---
#
# ### 6. *Quelles affirmations nécessitent un fact-check en priorité ?*
#
# Les affirmations prioritaires pour le fact-check sont :
#
# 1. **ID 6 (D5 - InfoVérité)**
#    Accusations graves, faux documents, impact politique et sociétal fort
#
# 2. **ID 1 (E5 - Vérité Énergie France)**
#    Appel massif au partage, rumeur de scandale, forte charge émotionnelle
#
# 3. **ID 9 (E4 - Équipe Le Patriote)**
#    Instrumentalisation politique, manipulation médiatique alléguée
#
# Ces contenus combinent :
# - **faible crédibilité**
# - **fort impact narratif**
# - **risque élevé de diffusion virale**
